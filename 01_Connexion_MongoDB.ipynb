# %%
# !pip install pymongo pandas requests schedule
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from pymongo import MongoClient

try:
    # Connexion à MongoDB
    client = MongoClient("mongodb://localhost:27017/")

    # Vérifier la connexion
    client.admin.command("ping")

    print(" Connexion réussie avec MongoDB !")

except Exception as e:
    print(" Erreur :", e)
# Out:
#  Connexion réussie avec MongoDB !

# %%
from pymongo import MongoClient

client = MongoClient("mongodb://localhost:27017/")

# Création de la base de données
db = client["ETL_Project"]

print("Base de données créée :", db.name)
# Out:
# Base de données créée : ETL_Project

# %%
# Création de la collection
collection = db["products"]

print("Collection créée :", collection.name)
# Out:
# Collection créée : products

# %%
# Insertion d'un document
product = {
    "name": "Laptop",
    "price": 1200,
    "category": "Informatique",
    "stock": 15
}

result = collection.insert_one(product)

print("Document inséré avec l'ID :", result.inserted_id)
# Out:
# Document inséré avec l'ID : 6a64a171c51f34f54a5f249a

# %%
# Affichage des documents
for doc in collection.find():
    print(doc)
# Out:
# {'_id': ObjectId('6a64a171c51f34f54a5f249a'), 'name': 'Laptop', 'price': 1200, 'category': 'Informatique', 'stock': 15}
